# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## EDA

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  21877.000000  21877.000000  21877.000000  21877.000000  21877.000000
# mean   16923.586689     -0.241062      0.222117      0.737919      0.262269
# std    11005.194861      1.880944      1.518145      1.740987      1.451003
# min        0.000000    -30.552380    -40.978852    -31.103685     -5.172595
# 25%     5495.000000     -0.960944     -0.350080      0.297985     -0.648858
# 50%    18769.000000     -0.299324      0.206459      0.888766      0.222377
# 75%    27778.000000      1.164879      0.858520      1.520392      1.132696
# max    31907.000000      1.960497     16.713389      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  21877.000000  21877.000000  21877.000000  21877.000000  21877.000000
# mean      -0.175253      0.087517     -0.141050      0.019343      0.562077
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21877 entries, 0 to 21876
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    21877 non-null  int64
#  1   V1      21877 non-null  float64
#  2   V2      21877 non-null  float64
#  3   V3      21877 non-null  float64
#  4   V4      21877 non-null  float64
#  5   V5      21877 non-null  float64
#  6   V6      21877 non-null  float64
#  7   V7      21877 non-null  float64
#  8   V8      21877 non-null  float64
#  9   V9      21877 non-null  float64
#  10  V10     21877 non-null  float64
#  11  V11     21877 non-null  float64
#  12  V12     21877 non-null  float64
#  13  V13     21877 non-null  float64
#  14  V14     21877 non-null  float64
#  15  V15     21877 non-null  float64
#  16  V16     21877 non-null  float64
#  17  V17     21877 non-null  float64
#  18  V18     21877 non-null  float64
#  19  V19     21877 non-null  float64
# ...

# %%
plt.figure(figsize=(25,15)) 
sns.heatmap(data.corr(), annot=True, linewidths=.3, fmt= '.2f',cmap='viridis')
plt.show()

# %% [markdown]
# **Handling Imbalance Dataset**

# %%
sns.countplot(x=data.iloc[:,-1],data=data,palette='rainbow')
plt.show()

# %%
X=data.iloc[:,:-1]
y=data['Class']

# %%
y.value_counts()
# Out:
# 0.0    21791
# 1.0       86
# Name: Class, dtype: int64

# %%
#oversampling
from imblearn.over_sampling import SMOTE #create synthetic/artificial points
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
y.value_counts() #balance
# Out:
# 0.0    21791
# 1.0    21791
# Name: Class, dtype: int64

# %%
sns.countplot(x=y,data=data,palette='rainbow')
plt.show()

# %% [markdown]
# **Training the Model**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=64)

# %%
from sklearn.svm import SVC
model=SVC(kernel='linear')
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=model.predict(X_test)

# %%
Y_pred1=model.predict(X_train)

# %% [markdown]
# **Performance**

# %%
#testing accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9865779511299759

# %%
#training accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_train,Y_pred1)
# Out:
# 0.9868636168076867

# %%
# testing
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      4389
#          1.0       0.99      0.98      0.99      4328
#
#     accuracy                           0.99      8717
#    macro avg       0.99      0.99      0.99      8717
# weighted avg       0.99      0.99      0.99      8717
